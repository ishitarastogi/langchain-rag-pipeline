# %%
import pymupdf

doc = pymupdf.open("../data/text_files/Reliance.pdf")

print("Pages:", doc.page_count)
print("Metadata:", doc.metadata)
doc.page_count       # 174
doc.metadata         # dict: producer, creator, title, author, creationDate
print(doc.name)             # the file path
print(doc.is_encrypted)     # whether it's password-protected
print(doc.get_toc())        # table of contents, if the PDF has bookmarks
print(doc[50].get_text()[:300])
print()
print(doc[50].get_text("blocks")[:3])
page = doc[0]
text = page.get_text()

print(len(text))
print(text)
# Out:
# Pages: 174
# Metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Vaishnavi Gangrade', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word 2016', 'producer': 'Microsoft® Word 2016', 'creationDate': "D:20250807112354+05'30'", 'modDate': "D:20250807113349+05'30'", 'trapped': '', 'encryption': None}
# ../data/text_files/Reliance.pdf
# False
# []
# APPENDIX I
# Identified Sustainability Information subject to Reasonable Assurance
# Sr.
# No.
# Reporting Standard Reference
# Indicator Number
# Boundary
# GRI Standards Disclosures presented in Integrated Annual Report
# 1
# Energy consumption within the organisation
# Total energy consumption (total electricity, t
#
# ...
