# %%
from docling.document_converter import DocumentConverter
from docling.datamodel.pipeline_options import PdfPipelineOptions
from docling.datamodel.base_models import InputFormat
from docling.document_converter import PdfFormatOption

# Faster settings
pipeline_options = PdfPipelineOptions()
pipeline_options.do_ocr = False
pipeline_options.do_table_structure = True

converter = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
    }
)

# Load the NVIDIA PDF
result = converter.convert(
    "../data/text_files/nvidia.pdf")   # Update path if needed
doc = result.document

print(f"Total tables found: {len(doc.tables)}")
print("-" * 60)

# Extract all tables
for i, table in enumerate(doc.tables):
    page_num = table.prov[0].page_no if table.prov else "Unknown"

    print(f"\n=== Table {i+1} (Page {page_num}) ===\n")

    # Export as Markdown (best for RAG)
    print(table.export_to_markdown(doc=doc))

    # Optional: as DataFrame
    # df = table.export_to_dataframe()
    # print(df)
